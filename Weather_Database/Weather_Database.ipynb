# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8b94438686b667fd01ab201eac1def50

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("----------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------
# Processing Record 1 of Set 1 | solovetskiy
# City not found. Skipping...
# Processing Record 2 of Set 1 | honiara
# Processing Record 3 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 1 | nicoya
# Processing Record 5 of Set 1 | pevek
# Processing Record 6 of Set 1 | oktyabrskiy
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | teguise
# Processing Record 14 of Set 1 | vao
# Processing Record 15 of Set 1 | fukuma
# Processing Record 16 of Set 1 | ostrovnoy
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | saint-francois
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | estevan
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 1 | alta floresta
# Processing Record 29 of Set 1 | noshiro
# Processing Record 30 of Set 1 | gizo
# Processing Record 31 of Set 1 | eyl
# Processing Record 32 of Set 1 | sangmelima
# Processing Record 33 of Set 1 | pangody
# Processing Record 34 of Set 1 | sumoto
# Processing Record 35 of Set 1 | mersing
# Processing Record 36 of Set 1 | comodoro rivadavia
# Processing Record 37 of Set 1 | ruteng
# Processing Record 38 of Set 1 | katherine
# Processing Record 39 of Set 1 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | qaanaaq
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | oranjemund
# Processing Record 45 of Set 1 | partizanskoye
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | naze
# Processing Record 48 of Set 1 | portland
# Processing Record 49 of Set 1 | selikhino
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | henties bay
# Processing Record 2 of Set 2 | hualmay
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | tipperary
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | port blair
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | kamaishi
# Processing Record 10 of Set 2 | plettenberg bay
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | longyearbyen
# Processing Record 13 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 2 | hami
# Processing Record 15 of Set 2 | epinal
# Processing Record 16 of Set 2 | reconquista
# Processing Record 17 of Set 2 | pisco
# Processing Record 18 of Set 2 | kavieng
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 2 | quime
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 25 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 2 | pimentel
# Processing Record 27 of Set 2 | zhangjiakou
# Processing Record 28 of Set 2 | constitucion
# Processing Record 29 of Set 2 | cherskiy
# Processing Record 30 of Set 2 | amahai
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | lakatoro
# Processing Record 33 of Set 2 | muisne
# Processing Record 34 of Set 2 | pandan
# Processing Record 35 of Set 2 | havoysund
# Processing Record 36 of Set 2 | lavrentiya
# Processing Record 37 of Set 2 | cap malheureux
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | vikhorevka
# Processing Record 40 of Set 2 | tiznit
# Processing Record 41 of Set 2 | kosh-agach
# Processing Record 42 of Set 2 | sao joao da barra
# Processing Record 43 of Set 2 | sechura
# Processing Record 44 of Set 2 | brownsville
# Processing Record 45 of Set 2 | hithadhoo
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | harrisonburg
# Processing Record 48 of Set 2 | victoria
# Processing Record 49 of Set 2 | tukrah
# Processing Record 50 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | tefe
# Processing Record 3 of Set 3 | kaitangata
# Processing Record 4 of Set 3 | port-gentil
# Processing Record 5 of Set 3 | lorengau
# Processing Record 6 of Set 3 | tuktoyaktuk
# Processing Record 7 of Set 3 | sokolo
# Processing Record 8 of Set 3 | sur
# Processing Record 9 of Set 3 | lieksa
# Processing Record 10 of Set 3 | lata
# Processing Record 11 of Set 3 | vostok
# Processing Record 12 of Set 3 | puerto colombia
# Processing Record 13 of Set 3 | russell
# Processing Record 14 of Set 3 | saint george
# Processing Record 15 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 3 | lompoc
# Processing Record 17 of Set 3 | madang
# Processing Record 18 of Set 3 | meulaboh
# Processing Record 19 of Set 3 | sao filipe
# Processing Record 20 of Set 3 | faanui
# Processing Record 21 of Set 3 | bengkulu
# Processing Record 22 of Set 3 | iqaluit
# Processing Record 23 of Set 3 | mataura
# Processing Record 24 of Set 3 | senanga
# Processing Record 25 of Set 3 | jacmel
# Processing Record 26 of Set 3 | dukat
# Processing Record 27 of Set 3 | kahului
# Processing Record 28 of Set 3 | colac
# Processing Record 29 of Set 3 | requena
# Processing Record 30 of Set 3 | guilin
# Processing Record 31 of Set 3 | asau
# Processing Record 32 of Set 3 | samarai
# Processing Record 33 of Set 3 | elblag
# Processing Record 34 of Set 3 | kysyl-syr
# Processing Record 35 of Set 3 | ribeira grande
# Processing Record 36 of Set 3 | garden city
# Processing Record 37 of Set 3 | teguldet
# Processing Record 38 of Set 3 | gat
# Processing Record 39 of Set 3 | leh
# Processing Record 40 of Set 3 | norman wells
# Processing Record 41 of Set 3 | belen
# Processing Record 42 of Set 3 | nanortalik
# Processing Record 43 of Set 3 | yellowknife
# Processing Record 44 of Set 3 | christchurch
# Processing Record 45 of Set 3 | port hardy
# Processing Record 46 of Set 3 | atuona
# Processing Record 47 of Set 3 | cape town
# Processing Record 48 of Set 3 | kavaratti
# Processing Record 49 of Set 3 | juifang
# City not found. Skipping...
# Processing Record 50 of Set 3 | waitati
# Processing Record 1 of Set 4 | quartucciu
# Processing Record 2 of Set 4 | puerto penasco
# Processing Record 3 of Set 4 | bilibino
# Processing Record 4 of Set 4 | marzuq
# Processing Record 5 of Set 4 | derzhavinsk
# Processing Record 6 of Set 4 | lampang
# Processing Record 7 of Set 4 | sobolevo
# Processing Record 8 of Set 4 | richards bay
# Processing Record 9 of Set 4 | ilulissat
# Processing Record 10 of Set 4 | caravelas
# Processing Record 11 of Set 4 | urucara
# Processing Record 12 of Set 4 | terrace
# Processing Record 13 of Set 4 | xihua
# Processing Record 14 of Set 4 | vila velha
# Processing Record 15 of Set 4 | adrar
# Processing Record 16 of Set 4 | upernavik
# Processing Record 17 of Set 4 | salamanca
# Processing Record 18 of Set 4 | deputatskiy
# Processing Record 19 of Set 4 | giyani
# Processing Record 20 of Set 4 | binga
# Processing Record 21 of Set 4 | mitsamiouli
# Processing Record 22 of Set 4 | wilkie
# Processing Record 23 of Set 4 | dossor
# Processing Record 24 of Set 4 | lebu
# Processing Record 25 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 4 | yatou
# Processing Record 27 of Set 4 | port augusta
# Processing Record 28 of Set 4 | souillac
# Processing Record 29 of Set 4 | havre-saint-pierre
# Processing Record 30 of Set 4 | dourbali
# Processing Record 31 of Set 4 | aleksandrov gay
# Processing Record 32 of Set 4 | raga
# Processing Record 33 of Set 4 | mahebourg
# Processing Record 34 of Set 4 | golyshmanovo
# Processing Record 35 of Set 4 | sistranda
# Processing Record 36 of Set 4 | shunyi
# Processing Record 37 of Set 4 | airai
# Processing Record 38 of Set 4 | khandyga
# Processing Record 39 of Set 4 | ust-maya
# Processing Record 40 of Set 4 | chokurdakh
# Processing Record 41 of Set 4 | vardo
# Processing Record 42 of Set 4 | burica
# City not found. Skipping...
# Processing Record 43 of Set 4 | east london
# Processing Record 44 of Set 4 | walvis bay
# Processing Record 45 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 4 | havlickuv brod
# Processing Record 47 of Set 4 | houma
# Processing Record 48 of Set 4 | katsuura
# Processing Record 49 of Set 4 | kongwa
# Processing Record 50 of Set 4 | safford
# Processing Record 1 of Set 5 | yeppoon
# Processing Record 2 of Set 5 | bintulu
# Processing Record 3 of Set 5 | husavik
# Processing Record 4 of Set 5 | torbay
# Processing Record 5 of Set 5 | kijang
# Processing Record 6 of Set 5 | erzincan
# Processing Record 7 of Set 5 | cidreira
# Processing Record 8 of Set 5 | dhola
# Processing Record 9 of Set 5 | puerto cabezas
# Processing Record 10 of Set 5 | stokmarknes
# Processing Record 11 of Set 5 | kirakira
# Processing Record 12 of Set 5 | guekedou
# City not found. Skipping...
# Processing Record 13 of Set 5 | pitimbu
# Processing Record 14 of Set 5 | key west
# Processing Record 15 of Set 5 | bud
# Processing Record 16 of Set 5 | lengshuitan
# Processing Record 17 of Set 5 | ucluelet
# Processing Record 18 of Set 5 | namatanai
# Processing Record 19 of Set 5 | mackay
# Processing Record 20 of Set 5 | antonina
# Processing Record 21 of Set 5 | pangnirtung
# Processing Record 22 of Set 5 | yar-sale
# Processing Record 23 of Set 5 | kapaa
# Processing Record 24 of Set 5 | baoding
# Processing Record 25 of Set 5 | tuatapere
# Processing Record 26 of Set 5 | bani walid
# Processing Record 27 of Set 5 | shu
# Processing Record 28 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 5 | vila franca do campo
# Processing Record 30 of Set 5 | fukue
# Processing Record 31 of Set 5 | clyde river
# Processing Record 32 of Set 5 | chara
# Processing Record 33 of Set 5 | padang
# Processing Record 34 of Set 5 | dubrovytsya
# Processing Record 35 of Set 5 | komsomolskiy
# Processing Record 36 of Set 5 | pathein
# Processing Record 37 of Set 5 | carlsbad
# Processing Record 38 of Set 5 | aykhal
# Processing Record 39 of Set 5 | jega
# Processing Record 40 of Set 5 | ugoofaaru
# Processing Record 41 of Set 5 | provideniya
# Processing Record 42 of Set 5 | kodiak
# Processing Record 43 of Set 5 | primo tapia
# Processing Record 44 of Set 5 | severo-kurilsk
# Processing Record 45 of Set 5 | quelimane
# Processing Record 46 of Set 5 | huilong
# Processing Record 47 of Set 5 | niigata
# Processing Record 48 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 5 | guadalupe victoria
# Processing Record 50 of Set 5 | yulara
# Processing Record 1 of Set 6 | chapais
# Processing Record 2 of Set 6 | kouango
# Processing Record 3 of Set 6 | belgrade
# Processing Record 4 of Set 6 | vernon
# Processing Record 5 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 6 of Set 6 | buchanan
# Processing Record 7 of Set 6 | labuhan
# Processing Record 8 of Set 6 | birjand
# Processing Record 9 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 6 | meadow lake
# Processing Record 11 of Set 6 | maasim
# Processing Record 12 of Set 6 | bethel
# Processing Record 13 of Set 6 | berlevag
# Processing Record 14 of Set 6 | goderich
# Processing Record 15 of Set 6 | tete
# Processing Record 16 of Set 6 | san policarpo
# Processing Record 17 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 6 | harbour breton
# Processing Record 19 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 6 | callaway
# Processing Record 21 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 6 | allonnes
# Processing Record 23 of Set 6 | bogande
# Processing Record 24 of Set 6 | yushu
# Processing Record 25 of Set 6 | beitbridge
# Processing Record 26 of Set 6 | esperance
# Processing Record 27 of Set 6 | westport
# Processing Record 28 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 29 of Set 6 | nitra
# Processing Record 30 of Set 6 | narsaq
# Processing Record 31 of Set 6 | ilo
# Processing Record 32 of Set 6 | flin flon
# Processing Record 33 of Set 6 | aksarka
# Processing Record 34 of Set 6 | kamenka
# Processing Record 35 of Set 6 | troitskoye
# Processing Record 36 of Set 6 | porto murtinho
# Processing Record 37 of Set 6 | san cristobal
# Processing Record 38 of Set 6 | lusambo
# Processing Record 39 of Set 6 | matara
# Processing Record 40 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 6 | coari
# Processing Record 42 of Set 6 | los llanos de aridane
# Processing Record 43 of Set 6 | kulhudhuffushi
# Processing Record 44 of Set 6 | puerto del rosario
# Processing Record 45 of Set 6 | pafos
# Processing Record 46 of Set 6 | dubbo
# Processing Record 47 of Set 6 | leningradskiy
# Processing Record 48 of Set 6 | tshela
# Processing Record 49 of Set 6 | ratnagiri
# Processing Record 50 of Set 6 | thinadhoo
# Processing Record 1 of Set 7 | saint anthony
# Processing Record 2 of Set 7 | bara
# Processing Record 3 of Set 7 | slyudyanka
# Processing Record 4 of Set 7 | jaguaruana
# Processing Record 5 of Set 7 | christiana
# Processing Record 6 of Set 7 | andenes
# Processing Record 7 of Set 7 | bagdarin
# Processing Record 8 of Set 7 | polovinnoye
# Processing Record 9 of Set 7 | college
# Processing Record 10 of Set 7 | katangli
# Processing Record 11 of Set 7 | batticaloa
# Processing Record 12 of Set 7 | nouadhibou
# Processing Record 13 of Set 7 | new norfolk
# Processing Record 14 of Set 7 | champerico
# Processing Record 15 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 16 of Set 7 | tigil
# Processing Record 17 of Set 7 | wichita
# Processing Record 18 of Set 7 | ojinaga
# Processing Record 19 of Set 7 | vero beach
# Processing Record 20 of Set 7 | bandarbeyla
# Processing Record 21 of Set 7 | mar del plata
# Processing Record 22 of Set 7 | ouallam
# Processing Record 23 of Set 7 | dolgoderevenskoye
# Processing Record 24 of Set 7 | beringovskiy
# Processing Record 25 of Set 7 | port lincoln
# Processing Record 26 of Set 7 | urubicha
# Processing Record 27 of Set 7 | bindi
# Processing Record 28 of Set 7 | lewistown
# Processing Record 29 of Set 7 | rio gallegos
# Processing Record 30 of Set 7 | khatanga
# Processing Record 31 of Set 7 | abha
# Processing Record 32 of Set 7 | kasongo-lunda
# Processing Record 33 of Set 7 | vila
# Processing Record 34 of Set 7 | mayor pablo lagerenza
# Processing Record 35 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 7 | carauari
# Processing Record 37 of Set 7 | lagoa
# Processing Record 38 of Set 7 | maragogi
# Processing Record 39 of Set 7 | fort nelson
# Processing Record 40 of Set 7 | klaksvik
# Processing Record 41 of Set 7 | cassilandia
# Processing Record 42 of Set 7 | smolenka
# Processing Record 43 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 7 | pirajui
# Processing Record 45 of Set 7 | guerrero negro
# Processing Record 46 of Set 7 | rovaniemi
# Processing Record 47 of Set 7 | atar
# Processing Record 48 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 49 of Set 7 | abu zabad
# Processing Record 50 of Set 7 | golden rock
# City not found. Skipping...
# Processing Record 1 of Set 8 | mastic beach
# Processing Record 2 of Set 8 | mount gambier
# Processing Record 3 of Set 8 | zhangye
# Processing Record 4 of Set 8 | diego de almagro
# Processing Record 5 of Set 8 | isangel
# Processing Record 6 of Set 8 | estancia
# Processing Record 7 of Set 8 | codrington
# Processing Record 8 of Set 8 | udachnyy
# Processing Record 9 of Set 8 | kaspiysk
# Processing Record 10 of Set 8 | sinnamary
# Processing Record 11 of Set 8 | cerrito
# Processing Record 12 of Set 8 | telimele
# Processing Record 13 of Set 8 | ampanihy
# Processing Record 14 of Set 8 | lasa
# Processing Record 15 of Set 8 | aden
# Processing Record 16 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 8 | nisia floresta
# Processing Record 18 of Set 8 | san patricio
# Processing Record 19 of Set 8 | beloha
# Processing Record 20 of Set 8 | cavalcante
# Processing Record 21 of Set 8 | gumla
# Processing Record 22 of Set 8 | penzance
# Processing Record 23 of Set 8 | aklavik
# Processing Record 24 of Set 8 | namtsy
# Processing Record 25 of Set 8 | saint marys
# Processing Record 26 of Set 8 | tura
# Processing Record 27 of Set 8 | geraldton
# Processing Record 28 of Set 8 | qaqortoq
# Processing Record 29 of Set 8 | bambous virieux
# Processing Record 30 of Set 8 | general roca
# Processing Record 31 of Set 8 | gouyave
# Processing Record 32 of Set 8 | amapa
# Processing Record 33 of Set 8 | west bay
# Processing Record 34 of Set 8 | arrifes
# Processing Record 35 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 8 | dingtao
# Processing Record 37 of Set 8 | kyabram
# Processing Record 38 of Set 8 | juneau
# Processing Record 39 of Set 8 | cabo san lucas
# Processing Record 40 of Set 8 | mayo
# Processing Record 41 of Set 8 | jaffna
# Processing Record 42 of Set 8 | vastervik
# City not found. Skipping...
# Processing Record 43 of Set 8 | talaya
# Processing Record 44 of Set 8 | biak
# Processing Record 45 of Set 8 | sabya
# Processing Record 46 of Set 8 | jieshi
# Processing Record 47 of Set 8 | cheremukhovo
# Processing Record 48 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 8 | talnakh
# Processing Record 50 of Set 8 | erenhot
# Processing Record 1 of Set 9 | anadyr
# Processing Record 2 of Set 9 | bunia
# Processing Record 3 of Set 9 | cuamba
# Processing Record 4 of Set 9 | teya
# Processing Record 5 of Set 9 | grand-santi
# Processing Record 6 of Set 9 | naudero
# Processing Record 7 of Set 9 | ancud
# Processing Record 8 of Set 9 | marti
# Processing Record 9 of Set 9 | izumo
# Processing Record 10 of Set 9 | port hedland
# Processing Record 11 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 9 | strezhevoy
# Processing Record 13 of Set 9 | tiksi
# Processing Record 14 of Set 9 | baykit
# Processing Record 15 of Set 9 | tlapacoyan
# Processing Record 16 of Set 9 | achisu
# Processing Record 17 of Set 9 | puerto carreno
# Processing Record 18 of Set 9 | margate
# Processing Record 19 of Set 9 | tsienyane
# City not found. Skipping...
# Processing Record 20 of Set 9 | poum
# Processing Record 21 of Set 9 | cayenne
# Processing Record 22 of Set 9 | yongan
# Processing Record 23 of Set 9 | karlstad
# Processing Record 24 of Set 9 | tema
# Processing Record 25 of Set 9 | athabasca
# Processing Record 26 of Set 9 | chigorodo
# Processing Record 27 of Set 9 | ayan
# Processing Record 28 of Set 9 | paracuru
# Processing Record 29 of Set 9 | skibbereen
# Processing Record 30 of Set 9 | hasaki
# Processing Record 31 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 32 of Set 9 | tias
# Processing Record 33 of Set 9 | chumphon
# Processing Record 34 of Set 9 | akdagmadeni
# Processing Record 35 of Set 9 | bubaque
# Processing Record 36 of Set 9 | bilma
# Processing Record 37 of Set 9 | grand gaube
# Processing Record 38 of Set 9 | laela
# Processing Record 39 of Set 9 | half moon bay
# Processing Record 40 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 41 of Set 9 | corinto
# Processing Record 42 of Set 9 | grindavik
# Processing Record 43 of Set 9 | sovetskiy
# Processing Record 44 of Set 9 | marrakesh
# Processing Record 45 of Set 9 | saquena
# Processing Record 46 of Set 9 | tautira
# Processing Record 47 of Set 9 | bolotnoye
# Processing Record 48 of Set 9 | linhares
# Processing Record 49 of Set 9 | balkanabat
# Processing Record 50 of Set 9 | ishigaki
# Processing Record 1 of Set 10 | aksum
# Processing Record 2 of Set 10 | konstantinovka
# Processing Record 3 of Set 10 | harnosand
# Processing Record 4 of Set 10 | manokwari
# Processing Record 5 of Set 10 | ankang
# Processing Record 6 of Set 10 | tabou
# Processing Record 7 of Set 10 | wasilla
# Processing Record 8 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 10 | namibe
# Processing Record 10 of Set 10 | ixtapa
# Processing Record 11 of Set 10 | toungoo
# City not found. Skipping...
# Processing Record 12 of Set 10 | san jorge
# Processing Record 13 of Set 10 | gijon
# Processing Record 14 of Set 10 | inhambane
# Processing Record 15 of Set 10 | hatfield
# Processing Record 16 of Set 10 | broome
# Processing Record 17 of Set 10 | shihezi
# Processing Record 18 of Set 10 | coquimbo
# Processing Record 19 of Set 10 | severnoye
# Processing Record 20 of Set 10 | chitral
# Processing Record 21 of Set 10 | borova
# Processing Record 22 of Set 10 | aginskoye
# Processing Record 23 of Set 10 | rocha
# Processing Record 24 of Set 10 | bodo
# Processing Record 25 of Set 10 | halmstad
# Processing Record 26 of Set 10 | payakumbuh
# Processing Record 27 of Set 10 | te anau
# Processing Record 28 of Set 10 | constantine
# Processing Record 29 of Set 10 | kingsland
# Processing Record 30 of Set 10 | panama city
# Processing Record 31 of Set 10 | port moresby
# Processing Record 32 of Set 10 | kaoma
# Processing Record 33 of Set 10 | poltava
# Processing Record 34 of Set 10 | griffith
# Processing Record 35 of Set 10 | omsukchan
# Processing Record 36 of Set 10 | lisakovsk
# Processing Record 37 of Set 10 | tessalit
# Processing Record 38 of Set 10 | lazaro cardenas
# Processing Record 39 of Set 10 | chaa-khol
# City not found. Skipping...
# Processing Record 40 of Set 10 | fare
# Processing Record 41 of Set 10 | le port
# Processing Record 42 of Set 10 | windhoek
# Processing Record 43 of Set 10 | linxia
# Processing Record 44 of Set 10 | ulladulla
# Processing Record 45 of Set 10 | kachug
# Processing Record 46 of Set 10 | lowestoft
# Processing Record 47 of Set 10 | kotido
# Processing Record 48 of Set 10 | suratgarh
# Processing Record 49 of Set 10 | elizabeth city
# Processing Record 50 of Set 10 | hasilpur
# Processing Record 1 of Set 11 | siguiri
# Processing Record 2 of Set 11 | antofagasta
# Processing Record 3 of Set 11 | conde
# Processing Record 4 of Set 11 | toora-khem
# Processing Record 5 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 11 | makakilo city
# Processing Record 7 of Set 11 | bako
# Processing Record 8 of Set 11 | sabha
# Processing Record 9 of Set 11 | banyo
# Processing Record 10 of Set 11 | turayf
# Processing Record 11 of Set 11 | hanyang
# Processing Record 12 of Set 11 | quatre cocos
# Processing Record 13 of Set 11 | touros
# Processing Record 14 of Set 11 | akyab
# Processing Record 15 of Set 11 | luderitz
# Processing Record 16 of Set 11 | riohacha
# Processing Record 17 of Set 11 | sola
# Processing Record 18 of Set 11 | eureka
# Processing Record 19 of Set 11 | salinopolis
# Processing Record 20 of Set 11 | la cruz
# Processing Record 21 of Set 11 | rosamorada
# Processing Record 22 of Set 11 | salalah
# Processing Record 23 of Set 11 | chenzhou
# Processing Record 24 of Set 11 | trois-pistoles
# City not found. Skipping...
# Processing Record 25 of Set 11 | neyvo-shaytanskiy
# Processing Record 26 of Set 11 | hambantota
# Processing Record 27 of Set 11 | falkenstein
# Processing Record 28 of Set 11 | nemuro
# Processing Record 29 of Set 11 | sao felix do xingu
# Processing Record 30 of Set 11 | bayan
# Processing Record 31 of Set 11 | mpanda
# Processing Record 32 of Set 11 | kolobrzeg
# Processing Record 33 of Set 11 | la ronge
# Processing Record 34 of Set 11 | rawson
# Processing Record 35 of Set 11 | vestmannaeyjar
# Processing Record 36 of Set 11 | normandin
# Processing Record 37 of Set 11 | ikeda
# Processing Record 38 of Set 11 | afgoye
# City not found. Skipping...
# Processing Record 39 of Set 11 | vanimo
# Processing Record 40 of Set 11 | barreirinha
# Processing Record 41 of Set 11 | xining
# Processing Record 42 of Set 11 | bol
# Processing Record 43 of Set 11 | tilichiki
# Processing Record 44 of Set 11 | svetlyy
# Processing Record 45 of Set 11 | gamba
# Processing Record 46 of Set 11 | pochutla
# Processing Record 47 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 11 | paamiut
# Processing Record 49 of Set 11 | martapura
# Processing Record 50 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 1 of Set 12 | banjar
# Processing Record 2 of Set 12 | biltine
# Processing Record 3 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 12 | thompson
# Processing Record 5 of Set 12 | kalemie
# Processing Record 6 of Set 12 | mananara
# Processing Record 7 of Set 12 | toulepleu
# City not found. Skipping...
# Processing Record 8 of Set 12 | antanifotsy
# Processing Record 9 of Set 12 | fairbanks
# Processing Record 10 of Set 12 | itoman
# Processing Record 11 of Set 12 | faya
# Processing Record 12 of Set 12 | yandoon
# City not found. Skipping...
# Processing Record 13 of Set 12 | sumbe
# Processing Record 14 of Set 12 | severodvinsk
# Processing Record 15 of Set 12 | tezu
# Processing Record 16 of Set 12 | rosetta
# Processing Record 17 of Set 12 | zaranj
# Processing Record 18 of Set 12 | baruun-urt
# Processing Record 19 of Set 12 | kochubey
# Processing Record 20 of Set 12 | nikolayevsk-na-amure
# Processing Record 21 of Set 12 | batagay-alyta
# Processing Record 22 of Set 12 | vung tau
# Processing Record 23 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 12 | puerto madryn
# Processing Record 25 of Set 12 | sitka
# Processing Record 26 of Set 12 | kisanga
# Processing Record 27 of Set 12 | apucarana
# Processing Record 28 of Set 12 | kruisfontein
# Processing Record 29 of Set 12 | kurumkan
# Processing Record 30 of Set 12 | changde
# Processing Record 31 of Set 12 | ruian
# City not found. Skipping...
# Processing Record 32 of Set 12 | inongo
# Processing Record 33 of Set 12 | cochabamba
# Processing Record 34 of Set 12 | la rioja
# Processing Record 35 of Set 12 | mount isa
# Processing Record 36 of Set 12 | andrews
# Processing Record 37 of Set 12 | sochi
# Processing Record 38 of Set 12 | qandala
# Processing Record 39 of Set 12 | abdanan
# Processing Record 40 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 41 of Set 12 | yerbogachen
# Processing Record 42 of Set 12 | kathmandu
# Processing Record 43 of Set 12 | aksaray
# Processing Record 44 of Set 12 | belaya gora
# Processing Record 45 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 12 | sawakin
# Processing Record 47 of Set 12 | hamilton
# Processing Record 48 of Set 12 | nelson bay
# Processing Record 49 of Set 12 | berbera
# Processing Record 50 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 13 | lubango
# Processing Record 2 of Set 13 | san jose
# Processing Record 3 of Set 13 | manbij
# Processing Record 4 of Set 13 | sao miguel do araguaia
# Processing Record 5 of Set 13 | ponta delgada
# Processing Record 6 of Set 13 | sabang
# Processing Record 7 of Set 13 | blagoyevo
# Processing Record 8 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 9 of Set 13 | uvarovo
# Processing Record 10 of Set 13 | nioki
# Processing Record 11 of Set 13 | at-bashi
# Processing Record 12 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 13 of Set 13 | shirochanka
# Processing Record 14 of Set 13 | vallenar
# Processing Record 15 of Set 13 | sokoni
# Processing Record 16 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 17 of Set 13 | huntingdon
# Processing Record 18 of Set 13 | itarema
# Processing Record 19 of Set 13 | vyartsilya
# Processing Record 20 of Set 13 | burlington
# Processing Record 21 of Set 13 | jutai
# Processing Record 22 of Set 13 | saint-pierre
# Processing Record 23 of Set 13 | nogent-le-rotrou
# Processing Record 24 of Set 13 | bagamoyo
# Processing Record 25 of Set 13 | anar darreh
# City not found. Skipping...
# Processing Record 26 of Set 13 | viedma
# Processing Record 27 of Set 13 | great yarmouth
# Processing Record 28 of Set 13 | lamesa
# Processing Record 29 of Set 13 | concepcion del uruguay
# Processing Record 30 of Set 13 | yeniseysk
# Processing Record 31 of Set 13 | priladozhskiy
# Processing Record 32 of Set 13 | nguruka
# Processing Record 33 of Set 13 | iracoubo
# Processing Record 34 of Set 13 | pinyug
# Processing Record 35 of Set 13 | pingliang
# Processing Record 36 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 13 | cockburn town
# Processing Record 38 of Set 13 | alibag
# Processing Record 39 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 13 | yanam
# Processing Record 41 of Set 13 | umm lajj
# Processing Record 42 of Set 13 | almonte
# Processing Record 43 of Set 13 | sundvollen
# City not found. Skipping...
# Processing Record 44 of Set 13 | springfield
# Processing Record 45 of Set 13 | dano
# Processing Record 46 of Set 13 | qasigiannguit
# Processing Record 47 of Set 13 | shingu
# Processing Record 48 of Set 13 | remanso
# Processing Record 49 of Set 13 | charo
# Processing Record 50 of Set 13 | adre
# Processing Record 1 of Set 14 | nyrob
# Processing Record 2 of Set 14 | bose
# Processing Record 3 of Set 14 | ahipara
# Processing Record 4 of Set 14 | mirskoy
# Processing Record 5 of Set 14 | dakar
# Processing Record 6 of Set 14 | male
# Processing Record 7 of Set 14 | victor harbor
# Processing Record 8 of Set 14 | port macquarie
# Processing Record 9 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 14 | kununurra
# Processing Record 11 of Set 14 | saint-joseph
# Processing Record 12 of Set 14 | hvide sande
# Processing Record 13 of Set 14 | povenets
# Processing Record 14 of Set 14 | kadnikov
# Processing Record 15 of Set 14 | thunder bay
# Processing Record 16 of Set 14 | tocopilla
# Processing Record 17 of Set 14 | broken hill
# Processing Record 18 of Set 14 | kirkuk
# Processing Record 19 of Set 14 | hovd
# Processing Record 20 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 21 of Set 14 | palmer
# Processing Record 22 of Set 14 | leamington
# Processing Record 23 of Set 14 | ilave
# Processing Record 24 of Set 14 | gwadar
# Processing Record 25 of Set 14 | aquiraz
# Processing Record 26 of Set 14 | jinchang
# Processing Record 27 of Set 14 | carlyle
# Processing Record 28 of Set 14 | tarko-sale
# Processing Record 29 of Set 14 | orotukan
# Processing Record 30 of Set 14 | watsa
# Processing Record 31 of Set 14 | ramgarh
# Processing Record 32 of Set 14 | takoradi
# Processing Record 33 of Set 14 | road town
# Processing Record 34 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 35 of Set 14 | teseney
# Processing Record 36 of Set 14 | iralaya
# Processing Record 37 of Set 14 | flinders
# Processing Record 38 of Set 14 | bridlington
# Processing Record 39 of Set 14 | ranong
# Processing Record 40 of Set 14 | arman
# Processing Record 41 of Set 14 | kenitra
# Processing Record 42 of Set 14 | saint-augustin
# Processing Record 43 of Set 14 | ewa beach
# Processing Record 44 of Set 14 | kumi
# Processing Record 45 of Set 14 | basco
# Processing Record 46 of Set 14 | langreo
# Processing Record 47 of Set 14 | morondava
# Processing Record 48 of Set 14 | karwar
# Processing Record 49 of Set 14 | bonthe
# Processing Record 50 of Set 14 | jhawarian
# Processing Record 1 of Set 15 | jinka
# Processing Record 2 of Set 15 | balkhash
# Processing Record 3 of Set 15 | pangkalanbuun
# Processing Record 4 of Set 15 | goma
# Processing Record 5 of Set 15 | sala
# Processing Record 6 of Set 15 | itaporanga
# Processing Record 7 of Set 15 | talgram
# Processing Record 8 of Set 15 | rayevskiy
# Processing Record 9 of Set 15 | liverpool
# Processing Record 10 of Set 15 | waingapu
# Processing Record 11 of Set 15 | ocampo
# Processing Record 12 of Set 15 | torgelow
# Processing Record 13 of Set 15 | rio verde de mato grosso
# Processing Record 14 of Set 15 | talcahuano
# Processing Record 15 of Set 15 | mecca
# Processing Record 16 of Set 15 | karpogory
# Processing Record 17 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 15 | alihe
# Processing Record 19 of Set 15 | kushima
# Processing Record 20 of Set 15 | savannah bight
# Processing Record 21 of Set 15 | isabela
# Processing Record 22 of Set 15 | omboue
# Processing Record 23 of Set 15 | madimba
# Processing Record 24 of Set 15 | aldan
# Processing Record 25 of Set 15 | methoni
# Processing Record 26 of Set 15 | sorland
# Processing Record 27 of Set 15 | karakol
# Processing Record 28 of Set 15 | jumla
# Processing Record 29 of Set 15 | astana
# Processing Record 30 of Set 15 | kalmunai
# Processing Record 31 of Set 15 | pasighat
# Processing Record 32 of Set 15 | sterling
# Processing Record 33 of Set 15 | taltal
# Processing Record 34 of Set 15 | praia
# Processing Record 35 of Set 15 | idaho falls
# Processing Record 36 of Set 15 | bac lieu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Honiara  -9.4333  159.9500     84.67        71          61        3.85
# 1       Nicoya  10.1483  -85.4520     71.60        94          75        5.75
# 2        Pevek  69.7008  170.3133     29.16        65          83       15.50
# 3  Oktyabrskiy  54.4815   53.4710     52.09        86          98        6.44
# 4       Albany  42.6001  -73.9662     59.00        77          90        5.75
#
#   Country Current Description
# 0      SB       broken clouds
# 1      CR       broken clouds
# 2      RU       broken clouds
# 3      RU     overcast clouds
# 4      US     overcast clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Honiara      SB  -9.4333  159.9500     84.67        71          61
# 1       Nicoya      CR  10.1483  -85.4520     71.60        94          75
# 2        Pevek      RU  69.7008  170.3133     29.16        65          83
# 3  Oktyabrskiy      RU  54.4815   53.4710     52.09        86          98
# 4       Albany      US  42.6001  -73.9662     59.00        77          90
#
#    Wind Speed Current Description
# 0        3.85       broken clouds
# 1        5.75       broken clouds
# 2       15.50       broken clouds
# 3        6.44     overcast clouds
# 4        5.75     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
